# %% [markdown]
# # Generate CLI commands to run `sbatch` on MareNostrum4
#
# This helper notebook helps users to generate `sbatch` commands to run different **GRN inference** or **community analysis** pipelines at scale on MareNostrum 4. The printed commands will be shown as outputs in the notebook that a user will have to run in the command line.
#
# ## Contacts
#
# For any problems/questions, please contact `mkriukov.job@gmail.com`.

# %% [markdown]
# ## Setting up namespace

# %%
import os  # file system
from termcolor import colored  # colored text output

import pandas as pd  # tabular data

# Setting working directory as home
home_dir = os.path.expanduser('~')
os.chdir(os.path.expanduser('~/scGRN_analysis'))

# Getting the tools for GRN analysis
import scGRN

# Setting up constants
cyan_color = lambda x: colored(x, 'cyan')
red_color = lambda x: colored(x, 'red')
green_color = lambda x: colored(x, 'green')

_NET_TYPES = ['all', 'TF', 'ctx']  # all gene-gene connections, TF-target connections, enriched TF-target connections

# Setting pathways to data files
_PROJ_HOME = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis'  # also scGRN._PROJ_HOME
_FMETA = f'{_PROJ_HOME}/Data_home/data/GSE145926_RAW/metadata.tsv'  # also scGRN._META_FILE
_DATA_HOME = f'{_PROJ_HOME}/Data_home/res/covid_19'  # also scGRN._DATA_HOME
_GREASY_DIR = f'{_PROJ_HOME}/sbatch/greasy'
_TF_LIST_lambert = f'{_PROJ_HOME}/Data_home/data/TF_lists/lambert2018.txt'

# Setting up available data
full_meta = scGRN.ana.get_meta(_DATA_HOME, _FMETA)

# Getting cell type count for each patient
full_cell_type_dist = full_meta.iloc[:, 3:]

# Getting information about all patients
_ALL_CELL_TYPES = full_cell_type_dist.columns.to_list()
_ALL_PATIENTS = full_meta.index.to_list()
_ALL_PAT_CELL_TYPES = {  # available cell types per patient
    pat: full_cell_type_dist.loc[pat].dropna().index.to_list() for pat in _ALL_PATIENTS
}
_ALL_PAT_FILENAMES = {  # obtained data files per patient
    pat: ['raw_data'] + list(map(lambda s: 'raw_data_' + s, cell_types)) for pat, cell_types in _ALL_PAT_CELL_TYPES.items()
}

# Displaying full metadata
print('Full metadata:')
full_meta
# Out:
# Full metadata:
#      group                                               file  num_cells  \
# id
# C51      C  /gpfs/projects/bsc08/shared_projects/scGRN_ana...     9431.0
# C52      C  /gpfs/projects/bsc08/shared_projects/scGRN_ana...     8696.0
# C100     C  /gpfs/projects/bsc08/shared_projects/scGRN_ana...      907.0
# C141     M  /gpfs/projects/bsc08/shared_projects/scGRN_ana...     1449.0
# C142     M  /gpfs/projects/bsc08/shared_projects/scGRN_ana...     1790.0
# C144     M  /gpfs/projects/bsc08/shared_projects/scGRN_ana...      452.0
# C143     S  /gpfs/projects/bsc08/shared_projects/scGRN_ana...    14933.0
# C145     S  /gpfs/projects/bsc08/shared_projects/scGRN_ana...    15550.0
# C146     S  /gpfs/projects/bsc08/shared_projects/scGRN_ana...     2545.0
# C148     S  /gpfs/projects/bsc08/shared_projects/scGRN_ana...     1165.0
# C149     S  /gpfs/projects/bsc08/shared_projects/scGRN_ana...     1936.0
# C152     S  /gpfs/projects/bsc08/shared_projects/scGRN_ana...     2557.0
#
#       Macrophage  T_cells     DC  Pre-B_cell_CD34-  Monocyte  NK_cell  B_cell  \
# id
# C51       8348.0    608.0  215.0              98.0      70.0     68.0     9.0
# C52       8611.0     13.0   23.0               3.0      14.0      5.0     2.0
# C100       338.0    411.0   45.0               5.0      51.0     20.0    12.0
# C141       197.0    932.0   48.0               5.0      86.0     96.0    33.0
# C142       482.0    996.0   39.0              13.0      67.0    113.0    20.0
# C144        37.0    181.0   41.0               8.0      73.0     34.0    14.0
# C143      2048.0   1394.0  154.0              33.0    7489.0    562.0    72.0
# C145      6960.0    719.0  859.0              46.0    5616.0    421.0    58.0
# C146       247.0     61.0   36.0               NaN     127.0     14.0     3.0
# C148        98.0    122.0   24.0               NaN     641.0     36.0     8.0
# C149       176.0    681.0   80.0               1.0     691.0     59.0    38.0
# C152       466.0    397.0   41.0             176.0     795.0     74.0   317.0
#
#       ...  Neutrophils   GMP  Erythroblast  Gametocytes  Neurons  Fibroblasts  \
# id    ...
# C51   ...          NaN   NaN           NaN          NaN      NaN          NaN
# C52   ...          NaN   NaN           NaN          NaN      NaN          NaN
# C100  ...          NaN   NaN           NaN          NaN      NaN          NaN
# C141  ...         11.0   1.0           NaN          NaN      NaN          NaN
# C142  ...         14.0   1.0           NaN          NaN      NaN          NaN
# C144  ...          3.0   NaN           2.0          NaN      NaN          NaN
# C143  ...       3005.0   2.0           NaN          2.0      1.0          NaN
# C145  ...        635.0   2.0           NaN          NaN      NaN          NaN
# C146  ...       1632.0   NaN           NaN          1.0      NaN          2.0
# C148  ...        178.0   1.0           NaN          1.0      NaN          NaN
# C149  ...        164.0   NaN           NaN          NaN      NaN          NaN
# C152  ...         30.0  13.0           NaN          NaN      NaN          NaN
#
#       Smooth_muscle_cells  Hepatocytes  Keratinocytes  Pro-Myelocyte
# id
# C51                   NaN          NaN            NaN            NaN
# C52                   NaN          NaN            NaN            NaN
# C100                  NaN          NaN            NaN            NaN
# C141                  NaN          NaN            NaN            NaN
# C142                  NaN          NaN            NaN            NaN
# C144                  NaN          NaN            NaN            NaN
# C143                  NaN          NaN            NaN            NaN
# C145                  NaN          NaN            NaN            NaN
# C146                  1.0          1.0            1.0            NaN
# C148                  NaN          NaN            NaN            NaN
# C149                  NaN          NaN            NaN            NaN
# C152                  NaN          NaN            NaN            1.0
#
# [12 rows x 25 columns]

# %% [markdown]
# ## `sc_pipeline` - Running single-cell processing using `Seurat` and `SingleR`
#
# Obtain `sbatch` commands to run the COVID-19 single cell data processing pipeline using `Seurat` package. The script is located in `scGRN/single_cell_processing/sc_pipeline/sc_pipeline.sh`.
#
# <font color=#8B8000>*Please move to* `scGRN/single_cell_processing/sc_pipeline` *or specify* `CURR_DIR="<PATH_TO_scGRN>/scGRN/single_cell_processing/sc_pipeline"` with `sc_pipeline.sh` script *in the cell below.*</font>

# %%
CURR_DIR = '/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/single_cell_processing/sc_pipeline'

# Current constants
META = '../sc_metadata.tsv'
OUT = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/res/covid_19'
ANNO = 'HumanPrimaryCellAtlasData'
ANNO_F = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/SingleR'
N_PROC = 12
PRE_MERGED = 'F'
SOBJ = 'T'
SFOBJ = 'F'
VERB = 'F'

log_folder = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/sbatch/logs'  # <- choose log folder!
log_out = os.path.join(log_folder, f'sc_pipeline_%j.out')
log_err = os.path.join(log_folder, f'sc_pipeline_%j.err')

cpus_per_task = 48
hours = 12

high_mem = False  # using high-memory nodes for large datasets
high_mem_cmd = f' {cyan_color("--constraint")}=highmem ' if high_mem else ' '  # formatting high_mem

qos_debug = True  # whether to use QOS queue (debug or not)
qos_debug_cmd = f' {cyan_color("--qos")}=debug ' if qos_debug else ' '  # formatting qos_debug
hours = 2 if qos_debug else hours  # decreasing the number of hours for debug mode

print(f"{red_color('sbatch')} {cyan_color('--time')}='{hours}:00:00'{qos_debug_cmd}{high_mem_cmd}{cyan_color('--cpus-per-task')}={cpus_per_task} "
      f"{cyan_color('--job-name')}='sc_pipeline' {cyan_color('--chdir')}={CURR_DIR} {cyan_color('--ntasks')}=1 "
      f"{cyan_color('--output')}={log_out} {cyan_color('--error')}={log_err} "
      f"{CURR_DIR}/{red_color('sc_pipeline.sh')} {META} {OUT} {ANNO} {ANNO_F} {N_PROC} {PRE_MERGED} {SOBJ} {SFOBJ} {VERB}")
# Out:
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='sc_pipeline' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/single_cell_processing/sc_pipeline --ntasks=1 --output=/gpfs/projects/bsc08/shared_projects/scGRN_analysis/sbatch/logs/sc_pipeline_%j.out --error=/gpfs/projects/bsc08/shared_projects/scGRN_analysis/sbatch/logs/sc_pipeline_%j.err /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/single_cell_processing/sc_pipeline/sc_pipeline.sh ../sc_metadata_debug.tsv /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/res/covid_19 HumanPrimaryCellAtlasData /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/SingleR 12 F T F F

# %% [markdown]
# ## `regulon_pipeline` pipeline - Regulon activity inference using `VIPER`
#
# Obtain `sbatch` command to run the **full** TF-target regulon activity using `VIPER` algorithm. The script is located in `scGRN/single_cell_processing/regulon_pipeline/regulon_pipeline.sh`
#
# <font color=#8B8000>*Please move to* `scGRN/single_cell_processing/regulon_pipeline` *or specify* `CURR_DIR="<PATH_TO_scGRN>/scGRN/single_cell_processing/regulon_pipeline"` with the `regulon_pipeline.sh` script *in the cell below.*</font>

# %%
CURR_DIR = '/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/single_cell_processing/regulon_pipeline'

# Current constants
META = '/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/single_cell_processing/sc_metadata_debug.tsv'
META_CTYPE = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/res/covid_19/cell_type_meta_debug.tsv'
OUT = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/res/covid_19'
REGULON = 'pyscenic'
Q_THRESH = 0.95
PLEIOT_CORR = 'T'
N_PROC = 12
SOBJ = 'T'
VERB = 'F'

log_folder = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/sbatch/logs'  # <- choose log folder!
log_out = os.path.join(log_folder, f'VIPER_{REGULON}_pipeline_%j.out')
log_err = os.path.join(log_folder, f'VIPER_{REGULON}_pipeline_%j.err')

cpus_per_task = 24
hours = 12

high_mem = False  # using high-memory nodes for large datasets
high_mem_cmd = f' {cyan_color("--constraint")}=highmem ' if high_mem else ' '  # formatting high_mem

qos_debug = True  # whether to use QOS queue (debug or not)
qos_debug_cmd = f' {cyan_color("--qos")}=debug ' if qos_debug else ' '  # formatting qos_debug
hours = 2 if qos_debug else hours  # decreasing the number of hours for debug mode

print(f"{red_color('sbatch')} {cyan_color('--time')}='{hours}:00:00'{qos_debug_cmd}{high_mem_cmd}{cyan_color('--cpus-per-task')}={cpus_per_task} "
      f"{cyan_color('--job-name')}='VIPER_{REGULON}_pipeline' {cyan_color('--chdir')}={CURR_DIR} {cyan_color('--ntasks')}=1 "
      f"{cyan_color('--output')}={log_out} {cyan_color('--error')}={log_err} "
      f"{CURR_DIR}/{red_color('regulon_pipeline.sh')} {META} {META_CTYPE} {OUT} {REGULON} {Q_THRESH} {PLEIOT_CORR} {N_PROC} {SOBJ} {VERB}")
# Out:
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='VIPER_pyscenic_pipeline' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/single_cell_processing/regulon_pipeline --ntasks=1 --output=/gpfs/projects/bsc08/shared_projects/scGRN_analysis/sbatch/logs/VIPER_pyscenic_pipeline_%j.out --error=/gpfs/projects/bsc08/shared_projects/scGRN_analysis/sbatch/logs/VIPER_pyscenic_pipeline_%j.err /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/single_cell_processing/regulon_pipeline/regulon_pipeline.sh /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/single_cell_processing/sc_metadata_debug.tsv /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/res/covid_19/cell_type_meta_debug.tsv /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/res/covid_19 pyscenic 0.95 T 12 T F

# %% [markdown]
# ## `network_inference` pipeline using `grnboost2` or `genie3`

# %% [markdown]
# ### Running for any scRNA-seq file
#
# Obtain `sbatch` command to run GRN inference **based on passed scRNA-seq matrix file** in `.tsv` format.
#
# <font color=#8B8000>*Please move to* `scGRN/network_inference` *or specify* `SCRIPT_DIR="<PATH_TO_scGRN>/scGRN/network_inference"` with `infer_GRN.sh` script *in the cell below.*</font>

# %%
# Main parameters
JOB_ID = 'debug_C51_T_cells'
SCRIPT_DIR = '/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference'
IN_PATH = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/res/covid_19/C51/data/Seurat/raw_data_T_cells.tsv'
OUT_PATH = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/debug'
LOG_FOLDER = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/sbatch/logs'
log_out = os.path.join(LOG_FOLDER, f'sc_pipeline_%j.out')
log_err = os.path.join(LOG_FOLDER, f'sc_pipeline_%j.err')

# Run parameters
method = 'grnboost2'
Q_THRESH = 0.95
hours = 40  # upper limit of hours
cpus_per_task = 48  # number of CPUs allocated per sbatch command
num_workers_per_task = 12  # the level of parallelization, the bigger - the higher parallelization

# Supplementary data
TF_LIST_PATH = _TF_LIST_lambert
DB_NAMES = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/SCENIC/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.feather'
MOTIF_ANNOTATION = '/gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/SCENIC/motifs-v9-nr.hgnc-m0.001-o0.0.tbl'

high_mem = False  # using high-memory nodes for large datasets
high_mem_cmd = f' {cyan_color("--constraint")}=highmem ' if high_mem else ' '  # formatting high_mem

qos_debug = True  # whether to use QOS queue (debug or not)
qos_debug_cmd = f' {cyan_color("--qos")}=debug ' if qos_debug else ' '  # formatting qos_debug
hours = 2 if qos_debug else hours  # decreasing the number of hours for debug mode

print(green_color('\nThe command for inferring TF-target network:'))
print(
    f"{red_color('sbatch')} {cyan_color('--time')}='{hours}:00:00'{qos_debug_cmd}{high_mem_cmd}{cyan_color('--cpus-per-task')}={cpus_per_task} "
    f"{cyan_color('--job-name')}='{JOB_ID}_TF_{method}' {cyan_color('--chdir')}={SCRIPT_DIR} {cyan_color('--ntasks')}=1 "
    f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
    f"{SCRIPT_DIR}/{red_color('infer_GRN.sh')} {method} {IN_PATH} {OUT_PATH} {num_workers_per_task} {Q_THRESH} {LOG_FOLDER} {TF_LIST_PATH} {DB_NAMES} {MOTIF_ANNOTATION}"
)
print(green_color('\nThe command for inferring gene-gene network:'))
print(
    f"{red_color('sbatch')} {cyan_color('--time')}='{hours}:00:00'{qos_debug_cmd}{high_mem_cmd}{cyan_color('--cpus-per-task')}={cpus_per_task} "
    f"{cyan_color('--job-name')}='{JOB_ID}_{method}' {cyan_color('--chdir')}={SCRIPT_DIR} {cyan_color('--ntasks')}=1 "
    f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
    f"{SCRIPT_DIR}/{red_color('infer_GRN.sh')} {method} {IN_PATH} {OUT_PATH} {num_workers_per_task} {Q_THRESH} {LOG_FOLDER}"
)
# Out:
# The command for inferring TF-target network:
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='debug_C51_T_cells_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference --ntasks=1 --output=/gpfs/projects/bsc08/shared_projects/scGRN_analysis/logs/sc_pipeline_%j.out --error=/gpfs/projects/bsc08/shared_projects/scGRN_analysis/logs/sc_pipeline_%j.err /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/infer_GRN.sh grnboost2 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/res/covid_19/C51/data/Seurat/raw_data_T_cells.tsv /gpfs/projects/bsc08/shared_projects/scGRN_analysis/logs 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/logs /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/SCENIC/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.feather /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/SCENIC/motifs-v9-nr.hgnc-m0.001-o0.0.tbl
#
# The command for inferring gene-gene network:
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='debug_C51_T_cells_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference --ntasks=1 --output=/gpfs/projects/bsc08/shared_projects/scGRN_analysis/logs/sc_pipeline_%j.out --error=/gpfs/projects/bsc08/shared_projects/scGRN_analysis/logs/sc_pipeline_%j.err /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/infer_GRN.sh grnboost2 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/res/covid_19/C51/data/Seurat/raw_data_T_cells.tsv /gpfs/projects/bsc08/shared_projects/scGRN_analysis/logs 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/logs

# %% [markdown]
# ### Patient-specific

# %% [markdown]
# #### Run separately
#
# Obtain `sbatch` commands to run **patient-specific** GRN inference pipelines (one per cell type available in corresponding patient). Please choose a `patient` for which we will produce a list of `sbatch` commands to run the GRN inference.
#
# <font color=#8B8000>*Please move to* `scGRN/network_inference/ana_scripts` *or specify* `SCRIPT_DIR="<PATH_TO_scGRN>/scGRN/network_inference/ana_scripts"` *with* `infer_pat_GRN.sh` *in the cell below.*</font>

# %%
CURR_DIR = '/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts'

# Current constants
patient = 'C51'  # choose a patient: C51 C52 C100 C141 C142 C144 C143 C145 C146 C148 C149 C152
method = 'grnboost2'
Q_THRESH = 0.95

data_ctypes = list(map(
    lambda x: x.replace('raw_data_', '') if x.replace('raw_data', '') else "''", 
    _ALL_PAT_FILENAMES[patient]
))

hours = 40  # upper limit of hours
cpus_per_task = 48  # number of CPUs allocated per sbatch command
num_workers_per_task = 8  # the level of parallelization, the bigger - the higher parallelization
high_mem = True if full_meta.loc[patient, 'num_cells'] > 10000 else False  # using high-memory nodes for large datasets
high_mem_cmd = f' {cyan_color("--constraint")}=highmem ' if high_mem else ' '  # formatting high_mem

qos_debug = True  # whether to use QOS queue (debug or not)
qos_debug_cmd = f' {cyan_color("--qos")}=debug ' if qos_debug else ' '  # formatting qos_debug
hours = 2 if qos_debug else hours  # decreasing the number of hours for debug mode

display(pd.DataFrame(full_cell_type_dist.loc[patient].dropna()).T)  # displaying the cell types in chosen patient

print(green_color('\nThe commands for inferring TF-target networks:'))
for d in data_ctypes:
    print(f"{red_color('sbatch')} {cyan_color('--time')}='{hours}:00:00'{qos_debug_cmd}{high_mem_cmd}{cyan_color('--cpus-per-task')}={cpus_per_task} "
          f"{cyan_color('--job-name')}='{patient}_{d}_TF_{method}' {cyan_color('--chdir')}={CURR_DIR} {cyan_color('--ntasks')}=1 "
          f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
          f"{CURR_DIR}/{red_color('infer_pat_GRN.sh')} {method} {patient} {d} {num_workers_per_task} {Q_THRESH} {_TF_LIST_lambert} SBATCH")
print(green_color('\nThe commands for inferring gene-gene networks:'))
for d in data_ctypes:
    print(f"{red_color('sbatch')} {cyan_color('--time')}='{hours}:00:00'{qos_debug_cmd}{high_mem_cmd}{cyan_color('--cpus-per-task')}={cpus_per_task} "
          f"{cyan_color('--job-name')}='{patient}_{d}_{method}' {cyan_color('--chdir')}={CURR_DIR} {cyan_color('--ntasks')}=1 "
          f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
          f"{CURR_DIR}/{red_color('infer_pat_GRN.sh')} {method} {patient} {d} {num_workers_per_task} {Q_THRESH} '' SBATCH")
# Out:
#      Macrophage  T_cells     DC  Pre-B_cell_CD34-  Monocyte  NK_cell  B_cell  \
# C51      8348.0    608.0  215.0              98.0      70.0     68.0     9.0
#
#      Epithelial_cells   BM  Pro-B_cell_CD34+  HSC_-G-CSF
# C51               7.0  4.0               3.0         1.0
# The commands for inferring TF-target networks:
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_''_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 '' 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_Macrophage_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 Macrophage 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_T_cells_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 T_cells 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_DC_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 DC 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_Pre-B_cell_CD34-_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 Pre-B_cell_CD34- 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_Monocyte_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 Monocyte 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_NK_cell_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 NK_cell 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_B_cell_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 B_cell 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_Epithelial_cells_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 Epithelial_cells 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_BM_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 BM 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_Pro-B_cell_CD34+_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 Pro-B_cell_CD34+ 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_HSC_-G-CSF_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 HSC_-G-CSF 8 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH
#
# The commands for inferring gene-gene networks:
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_''_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 '' 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_Macrophage_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 Macrophage 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_T_cells_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 T_cells 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_DC_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 DC 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_Pre-B_cell_CD34-_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 Pre-B_cell_CD34- 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_Monocyte_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 Monocyte 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_NK_cell_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 NK_cell 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_B_cell_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 B_cell 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_Epithelial_cells_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 Epithelial_cells 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_BM_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 BM 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_Pro-B_cell_CD34+_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 Pro-B_cell_CD34+ 8 0.95 '' SBATCH
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=48 --job-name='C51_HSC_-G-CSF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_pat_GRN.sh grnboost2 C51 HSC_-G-CSF 8 0.95 '' SBATCH

# %% [markdown]
# #### Run together using `greasy`
#
# Here we will use highly-parallelized `greasy` framework (one `greasy` run per patient for all available cell types in that patient). Aggregates the `sbatch` runs as one command. The cell below will generate `greasy` task files **for each patient** which the user can execute using `greasy_pat_GRN.sh`.
#
# <font color=#8B8000>*Please move to* `scGRN/network_inference/ana_scripts` *or specify* `SCRIPT_DIR="<PATH_TO_scGRN>/scGRN/network_inference/ana_scripts"` *with* `greasy_pat_GRN.sh` *in the cell below.*</font>

# %%
CURR_DIR = '/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts'

_PRINT_TASKS_HERE = False  # whether to print tasks here or save only in greasy task file

# Current constants
method = 'grnboost2'
Q_THRESH = 0.95

# Global configs
n_nodes = 4  # total number of nodes allocated to greasy job (1 node = 48 cores in MN4)
hours = 36  # upper limit of hours

for patient in _ALL_PATIENTS:
    
    data_ctypes = list(map(
        lambda x: x.replace('raw_data_', '') if x.replace('raw_data', '') else "''", 
        _ALL_PAT_FILENAMES[patient]
    ))    
    pat_ctype_count = full_meta.loc[patient].drop(['file', 'group']).dropna()

    GBs_per_worker = 8 if pat_ctype_count['num_cells'] < 8000 else 16  # number of gigabytes per one process
    cpus_per_worker = GBs_per_worker // 2  # calculate number of CPUs per process (low-mem nodes have 2 GB RAM per 1 CPU)
    cpus_per_task = cpus_per_worker * 4  # calculate number CPUs per greasy task
    total_avail_cpus = n_nodes * 48  # calculate total number of CPUs
    n_tasks = total_avail_cpus // cpus_per_task  # calculate number of greasy tasks executed simultaneously (normally `n_tasks` < `total_n_tasks`)
    num_workers_per_task = cpus_per_task // cpus_per_worker  # calculate number of parallel processes per task, level of parallelization

    qos_debug = False  # whether to use QOS queue (debug or not)
    qos_debug_cmd = f' {cyan_color("--qos")}=debug ' if qos_debug else ' '  # formatting qos_debug
    hours = 2 if qos_debug else hours  # decreasing the number of hours for debug mode

    # Print out the sbatch command to run greasy
    print(f"{red_color('sbatch')} {cyan_color('--job-name')}='GREASY_pat_{patient}_{method}' "
          f"{cyan_color('--ntasks')}={n_tasks} {cyan_color('--time')}='{hours}:00:00' "
          f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
          f"{cyan_color('--cpus-per-task')}={cpus_per_task}{qos_debug_cmd}"
          f"{CURR_DIR}/{red_color('greasy_pat_GRN.sh')} {method} {green_color(patient)}")

    # Generate list of tasks
    tasks = ''
    i = 1
    for d in data_ctypes:
        # TF-target tasks
        task_1 = f"{CURR_DIR}/infer_pat_GRN.sh {method} {patient} {d} {num_workers_per_task} {Q_THRESH} {_TF_LIST_lambert} GREASY {i}"
        if _PRINT_TASKS_HERE:
            print(task_1)
        tasks += f'{task_1}\n'
        i += 1
    print()
    for d in data_ctypes:
        # Gene-gene tasks
        task_2 = f"{CURR_DIR}/infer_pat_GRN.sh {method} {patient} {d} {num_workers_per_task} {Q_THRESH} '' GREASY {i}"
        if _PRINT_TASKS_HERE:
            print(task_2)
        i += 1
        tasks += f'{task_2}\n'
    if _PRINT_TASKS_HERE:
        print()
        print()

    tasks = tasks.strip()
    with open(f'{_GREASY_DIR}/greasy_tasks_pat_{patient}_{method}', 'w') as f:
        f.write(tasks)
        
print(f'The greasy task files is generated at directory: {green_color(_GREASY_DIR)}')
# Out:
# sbatch --job-name='GREASY_pat_C51_grnboost2' --ntasks=6 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=32 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C51
#
# sbatch --job-name='GREASY_pat_C52_grnboost2' --ntasks=6 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=32 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C52
#
# sbatch --job-name='GREASY_pat_C100_grnboost2' --ntasks=12 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C100
#
# sbatch --job-name='GREASY_pat_C141_grnboost2' --ntasks=12 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C141
#
# sbatch --job-name='GREASY_pat_C142_grnboost2' --ntasks=12 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C142
#
# sbatch --job-name='GREASY_pat_C144_grnboost2' --ntasks=12 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C144
#
# sbatch --job-name='GREASY_pat_C143_grnboost2' --ntasks=6 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=32 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C143
#
# sbatch --job-name='GREASY_pat_C145_grnboost2' --ntasks=6 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=32 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C145
#
# sbatch --job-name='GREASY_pat_C146_grnboost2' --ntasks=12 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C146
#
# sbatch --job-name='GREASY_pat_C148_grnboost2' --ntasks=12 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C148
#
# sbatch --job-name='GREASY_pat_C149_grnboost2' --ntasks=12 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C149
#
# sbatch --job-name='GREASY_pat_C152_grnboost2' --ntasks=12 --time='36:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16 /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_pat_GRN.sh grnboost2 C152
#
# The greasy task files is generated at directory: /gpfs/projects/bsc08/shared_projects/scGRN_analysis/sbatch/greasy

# %% [markdown]
# ### Cell type-specific
# #### Run separately
#
# Obtain `sbatch` commands to run **cell type-specific** GRN inference pipelines (patient-aggregated per each cell type). For each cell type we will have 4 GRN inference runs:
# - based on all cells
# - based on cells from control (C) patients
# - based on cells from mild (M) patients
# - based on cells from severe (S) patients
#
# <font color=#8B8000>*Please move to* `scGRN/network_inference/ana_scripts` *or specify* `SCRIPT_DIR="<PATH_TO_scGRN>/scGRN/network_inference/ana_scripts"` *with* `infer_agg_GRN.sh` *in the cell below.*</font>

# %%
CURR_DIR = '/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts'

# Current constants
method = 'grnboost2'
pat_types = ['all_patients', 'C', 'M', 'S']
data_sizes = full_meta.sum()[2:].sort_values(ascending=False).rename(index={'num_cells': 'all_data'})
Q_THRESH = 0.95

# Report number of cells for each cell types
display(pd.DataFrame(full_cell_type_dist.sum().sort_values(ascending=False).rename('Number of cells')).T)

i = 1

for cell_type, data_size in data_sizes.items():
    print(green_color(f'The cell type: {cell_type}'))
    for pat_type in pat_types:
        
        hours = 48 if data_size > 8000 else 24  # upper limit of hours
        cpus_per_task = 48 if data_size > 8000 else 24  # number of CPUs allocated per sbatch command
        num_workers_per_task = 12  # the level of parallelization, the bigger - the higher parallelization
        high_mem = True if data_size > 10000 else False  # using high-memory nodes for large datasets
        high_mem_cmd = f' {cyan_color("--constraint")}=highmem ' if high_mem else ' '  # formatting high_mem
        
        qos_debug = True  # whether to use QOS queue (debug or not)
        qos_debug_cmd = f' {cyan_color("--qos")}=debug ' if qos_debug else ' '  # formatting qos_debug
        hours = 2 if qos_debug else hours  # decreasing the number of hours for debug mode

        # Printing commands for TF-target networks
        print(f"{red_color('sbatch')} {cyan_color('--time')}='{hours}:00:00'{qos_debug_cmd}{high_mem_cmd}{cyan_color('--cpus-per-task')}={cpus_per_task} "
              f"{cyan_color('--job-name')}='{cell_type}_{pat_type}_TF_{method}' {cyan_color('--chdir')}={CURR_DIR} {cyan_color('--ntasks')}=1 "
              f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
              f"{CURR_DIR}/{red_color('infer_agg_GRN.sh')} {method} {cell_type} {green_color(pat_type)} {num_workers_per_task} {Q_THRESH} {_TF_LIST_lambert} SBATCH {i}")
        i += 1
        # Printing commands for gene-gene networks
        print(f"{red_color('sbatch')} {cyan_color('--time')}='{hours}:00:00'{qos_debug_cmd}{high_mem_cmd}{cyan_color('--cpus-per-task')}={cpus_per_task} "
              f"{cyan_color('--job-name')}='{cell_type}_{pat_type}_{method}' {cyan_color('--chdir')}={CURR_DIR} {cyan_color('--ntasks')}=1 "
              f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
              f"{CURR_DIR}/{red_color('infer_agg_GRN.sh')} {method} {cell_type} {green_color(pat_type)} {num_workers_per_task} {Q_THRESH} '' SBATCH {i}")
        i += 1
        print()
    print()
# Out:
#                  Macrophage  Monocyte  T_cells  Neutrophils      DC  NK_cell  \
# Number of cells     28008.0   15720.0   6515.0       5672.0  1605.0   1502.0
#
#                  Epithelial_cells  B_cell  Pre-B_cell_CD34-  HSC_-G-CSF  ...  \
# Number of cells            1242.0   586.0             388.0        61.0  ...
#
#                   CMP    BM  Gametocytes  Erythroblast  Fibroblasts  Neurons  \
# Number of cells  16.0  13.0          4.0           2.0          2.0      1.0
#
#                  Smooth_muscle_cells  Hepatocytes  Keratinocytes  \
# Number of cells                  1.0          1.0            1.0
#
#                  Pro-Myelocyte
# Number of cells            1.0
#
# [1 rows x 22 columns]
# The cell type: all_data
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='all_data_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 all_data all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 1
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='all_data_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 all_data all_patients 12 0.95 '' SBATCH 2
#
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='all_data_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 all_data C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 3
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='all_data_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 all_data C 12 0.95 '' SBATCH 4
#
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='all_data_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 all_data M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 5
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='all_data_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 all_data M 12 0.95 '' SBATCH 6
#
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='all_data_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 all_data S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 7
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='all_data_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 all_data S 12 0.95 '' SBATCH 8
#
#
# The cell type: Macrophage
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Macrophage_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Macrophage all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 9
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Macrophage_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Macrophage all_patients 12 0.95 '' SBATCH 10
#
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Macrophage_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Macrophage C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 11
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Macrophage_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Macrophage C 12 0.95 '' SBATCH 12
#
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Macrophage_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Macrophage M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 13
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Macrophage_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Macrophage M 12 0.95 '' SBATCH 14
#
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Macrophage_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Macrophage S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 15
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Macrophage_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Macrophage S 12 0.95 '' SBATCH 16
#
#
# The cell type: Monocyte
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Monocyte_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Monocyte all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 17
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Monocyte_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Monocyte all_patients 12 0.95 '' SBATCH 18
#
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Monocyte_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Monocyte C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 19
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Monocyte_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Monocyte C 12 0.95 '' SBATCH 20
#
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Monocyte_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Monocyte M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 21
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Monocyte_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Monocyte M 12 0.95 '' SBATCH 22
#
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Monocyte_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Monocyte S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 23
# sbatch --time='2:00:00' --qos=debug  --constraint=highmem --cpus-per-task=48 --job-name='Monocyte_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Monocyte S 12 0.95 '' SBATCH 24
#
#
# The cell type: T_cells
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='T_cells_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 T_cells all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 25
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='T_cells_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 T_cells all_patients 12 0.95 '' SBATCH 26
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='T_cells_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 T_cells C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 27
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='T_cells_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 T_cells C 12 0.95 '' SBATCH 28
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='T_cells_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 T_cells M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 29
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='T_cells_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 T_cells M 12 0.95 '' SBATCH 30
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='T_cells_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 T_cells S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 31
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='T_cells_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 T_cells S 12 0.95 '' SBATCH 32
#
#
# The cell type: Neutrophils
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neutrophils_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neutrophils all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 33
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neutrophils_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neutrophils all_patients 12 0.95 '' SBATCH 34
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neutrophils_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neutrophils C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 35
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neutrophils_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neutrophils C 12 0.95 '' SBATCH 36
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neutrophils_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neutrophils M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 37
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neutrophils_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neutrophils M 12 0.95 '' SBATCH 38
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neutrophils_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neutrophils S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 39
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neutrophils_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neutrophils S 12 0.95 '' SBATCH 40
#
#
# The cell type: DC
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='DC_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 DC all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 41
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='DC_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 DC all_patients 12 0.95 '' SBATCH 42
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='DC_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 DC C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 43
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='DC_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 DC C 12 0.95 '' SBATCH 44
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='DC_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 DC M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 45
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='DC_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 DC M 12 0.95 '' SBATCH 46
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='DC_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 DC S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 47
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='DC_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 DC S 12 0.95 '' SBATCH 48
#
#
# The cell type: NK_cell
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='NK_cell_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 NK_cell all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 49
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='NK_cell_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 NK_cell all_patients 12 0.95 '' SBATCH 50
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='NK_cell_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 NK_cell C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 51
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='NK_cell_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 NK_cell C 12 0.95 '' SBATCH 52
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='NK_cell_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 NK_cell M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 53
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='NK_cell_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 NK_cell M 12 0.95 '' SBATCH 54
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='NK_cell_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 NK_cell S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 55
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='NK_cell_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 NK_cell S 12 0.95 '' SBATCH 56
#
#
# The cell type: Epithelial_cells
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Epithelial_cells_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Epithelial_cells all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 57
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Epithelial_cells_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Epithelial_cells all_patients 12 0.95 '' SBATCH 58
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Epithelial_cells_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Epithelial_cells C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 59
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Epithelial_cells_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Epithelial_cells C 12 0.95 '' SBATCH 60
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Epithelial_cells_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Epithelial_cells M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 61
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Epithelial_cells_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Epithelial_cells M 12 0.95 '' SBATCH 62
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Epithelial_cells_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Epithelial_cells S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 63
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Epithelial_cells_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Epithelial_cells S 12 0.95 '' SBATCH 64
#
#
# The cell type: B_cell
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='B_cell_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 B_cell all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 65
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='B_cell_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 B_cell all_patients 12 0.95 '' SBATCH 66
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='B_cell_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 B_cell C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 67
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='B_cell_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 B_cell C 12 0.95 '' SBATCH 68
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='B_cell_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 B_cell M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 69
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='B_cell_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 B_cell M 12 0.95 '' SBATCH 70
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='B_cell_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 B_cell S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 71
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='B_cell_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 B_cell S 12 0.95 '' SBATCH 72
#
#
# The cell type: Pre-B_cell_CD34-
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pre-B_cell_CD34-_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pre-B_cell_CD34- all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 73
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pre-B_cell_CD34-_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pre-B_cell_CD34- all_patients 12 0.95 '' SBATCH 74
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pre-B_cell_CD34-_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pre-B_cell_CD34- C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 75
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pre-B_cell_CD34-_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pre-B_cell_CD34- C 12 0.95 '' SBATCH 76
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pre-B_cell_CD34-_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pre-B_cell_CD34- M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 77
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pre-B_cell_CD34-_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pre-B_cell_CD34- M 12 0.95 '' SBATCH 78
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pre-B_cell_CD34-_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pre-B_cell_CD34- S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 79
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pre-B_cell_CD34-_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pre-B_cell_CD34- S 12 0.95 '' SBATCH 80
#
#
# The cell type: HSC_-G-CSF
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='HSC_-G-CSF_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 HSC_-G-CSF all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 81
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='HSC_-G-CSF_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 HSC_-G-CSF all_patients 12 0.95 '' SBATCH 82
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='HSC_-G-CSF_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 HSC_-G-CSF C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 83
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='HSC_-G-CSF_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 HSC_-G-CSF C 12 0.95 '' SBATCH 84
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='HSC_-G-CSF_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 HSC_-G-CSF M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 85
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='HSC_-G-CSF_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 HSC_-G-CSF M 12 0.95 '' SBATCH 86
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='HSC_-G-CSF_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 HSC_-G-CSF S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 87
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='HSC_-G-CSF_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 HSC_-G-CSF S 12 0.95 '' SBATCH 88
#
#
# The cell type: Pro-B_cell_CD34+
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-B_cell_CD34+_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-B_cell_CD34+ all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 89
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-B_cell_CD34+_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-B_cell_CD34+ all_patients 12 0.95 '' SBATCH 90
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-B_cell_CD34+_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-B_cell_CD34+ C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 91
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-B_cell_CD34+_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-B_cell_CD34+ C 12 0.95 '' SBATCH 92
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-B_cell_CD34+_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-B_cell_CD34+ M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 93
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-B_cell_CD34+_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-B_cell_CD34+ M 12 0.95 '' SBATCH 94
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-B_cell_CD34+_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-B_cell_CD34+ S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 95
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-B_cell_CD34+_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-B_cell_CD34+ S 12 0.95 '' SBATCH 96
#
#
# The cell type: GMP
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='GMP_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 GMP all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 97
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='GMP_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 GMP all_patients 12 0.95 '' SBATCH 98
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='GMP_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 GMP C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 99
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='GMP_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 GMP C 12 0.95 '' SBATCH 100
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='GMP_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 GMP M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 101
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='GMP_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 GMP M 12 0.95 '' SBATCH 102
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='GMP_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 GMP S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 103
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='GMP_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 GMP S 12 0.95 '' SBATCH 104
#
#
# The cell type: CMP
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='CMP_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 CMP all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 105
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='CMP_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 CMP all_patients 12 0.95 '' SBATCH 106
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='CMP_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 CMP C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 107
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='CMP_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 CMP C 12 0.95 '' SBATCH 108
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='CMP_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 CMP M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 109
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='CMP_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 CMP M 12 0.95 '' SBATCH 110
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='CMP_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 CMP S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 111
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='CMP_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 CMP S 12 0.95 '' SBATCH 112
#
#
# The cell type: BM
# ...
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neurons_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neurons C 12 0.95 '' SBATCH 148
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neurons_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neurons M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 149
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neurons_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neurons M 12 0.95 '' SBATCH 150
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neurons_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neurons S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 151
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Neurons_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Neurons S 12 0.95 '' SBATCH 152
#
#
# The cell type: Smooth_muscle_cells
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Smooth_muscle_cells_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Smooth_muscle_cells all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 153
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Smooth_muscle_cells_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Smooth_muscle_cells all_patients 12 0.95 '' SBATCH 154
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Smooth_muscle_cells_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Smooth_muscle_cells C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 155
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Smooth_muscle_cells_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Smooth_muscle_cells C 12 0.95 '' SBATCH 156
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Smooth_muscle_cells_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Smooth_muscle_cells M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 157
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Smooth_muscle_cells_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Smooth_muscle_cells M 12 0.95 '' SBATCH 158
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Smooth_muscle_cells_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Smooth_muscle_cells S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 159
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Smooth_muscle_cells_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Smooth_muscle_cells S 12 0.95 '' SBATCH 160
#
#
# The cell type: Hepatocytes
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Hepatocytes_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Hepatocytes all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 161
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Hepatocytes_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Hepatocytes all_patients 12 0.95 '' SBATCH 162
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Hepatocytes_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Hepatocytes C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 163
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Hepatocytes_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Hepatocytes C 12 0.95 '' SBATCH 164
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Hepatocytes_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Hepatocytes M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 165
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Hepatocytes_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Hepatocytes M 12 0.95 '' SBATCH 166
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Hepatocytes_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Hepatocytes S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 167
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Hepatocytes_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Hepatocytes S 12 0.95 '' SBATCH 168
#
#
# The cell type: Keratinocytes
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Keratinocytes_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Keratinocytes all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 169
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Keratinocytes_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Keratinocytes all_patients 12 0.95 '' SBATCH 170
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Keratinocytes_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Keratinocytes C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 171
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Keratinocytes_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Keratinocytes C 12 0.95 '' SBATCH 172
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Keratinocytes_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Keratinocytes M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 173
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Keratinocytes_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Keratinocytes M 12 0.95 '' SBATCH 174
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Keratinocytes_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Keratinocytes S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 175
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Keratinocytes_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Keratinocytes S 12 0.95 '' SBATCH 176
#
#
# The cell type: Pro-Myelocyte
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-Myelocyte_all_patients_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-Myelocyte all_patients 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 177
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-Myelocyte_all_patients_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-Myelocyte all_patients 12 0.95 '' SBATCH 178
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-Myelocyte_C_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-Myelocyte C 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 179
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-Myelocyte_C_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-Myelocyte C 12 0.95 '' SBATCH 180
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-Myelocyte_M_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-Myelocyte M 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 181
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-Myelocyte_M_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-Myelocyte M 12 0.95 '' SBATCH 182
#
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-Myelocyte_S_TF_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-Myelocyte S 12 0.95 /gpfs/projects/bsc08/shared_projects/scGRN_analysis/Data_home/data/TF_lists/lambert2018.txt SBATCH 183
# sbatch --time='2:00:00' --qos=debug  --cpus-per-task=24 --job-name='Pro-Myelocyte_S_grnboost2' --chdir=/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts --ntasks=1 --output=/dev/null --error=/dev/null /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/infer_agg_GRN.sh grnboost2 Pro-Myelocyte S 12 0.95 '' SBATCH 184

# %% [markdown]
# #### Run together using `greasy`
#
# Here we will use highly-parallelized `greasy` framework (one `greasy` run per cell type for all available patient types where such cell type is present). Aggregates the `sbatch` runs as one command. The cell below will generate `greasy` task files **for cell type** which the user can execute using `greasy_agg_GRN.sh`.
#
# <font color=#8B8000>*Please move to* `scGRN/network_inference/ana_scripts` *or specify* `SCRIPT_DIR="<PATH_TO_scGRN>/scGRN/network_inference/ana_scripts"` *with* `greasy_agg_GRN.sh` *in the cell below.*</font>

# %%
CURR_DIR = '/gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts'

_PRINT_TASKS_HERE = False  # whether to print tasks here or save only in greasy task file

# Current constants
method = 'grnboost2'
pat_types = ['all_patients', 'C', 'M', 'S']
data_sizes = full_meta.sum()[2:].sort_values(ascending=False).rename(index={'num_cells': 'all_data'})
Q_THRESH = 0.95

# Global configs
n_nodes = 4  # total number of nodes allocated to greasy job (1 node = 48 cores in MN4)
hours = 48  # upper limit of hours

for cell_type, data_size in data_sizes.items():
    
    cell_count = scGRN.ana.get_num_cells(pat='all', cell_type=cell_type, meta=full_meta)

    GBs_per_worker = 8 if cell_count < 8000 else 16 if cell_count < 20000 else 24 # number of gigabytes per one process
    cpus_per_worker = GBs_per_worker // 2  # calculate number of CPUs per process (low-mem nodes have 2 GB RAM per 1 CPU)
    cpus_per_task = cpus_per_worker * 4  # calculate number CPUs per greasy task
    total_avail_cpus = n_nodes * 48  # calculate total number of CPUs
    n_tasks = total_avail_cpus // cpus_per_task  # calculate number of greasy tasks executed simultaneously (normally `n_tasks` < `total_n_tasks`)
    num_workers_per_task = cpus_per_task // cpus_per_worker  # calculate number of parallel processes per task, level of parallelization

    high_mem = True if data_size > 10000 else False  # using high-memory nodes for large datasets
    high_mem_cmd = f' {cyan_color("--constraint")}=highmem ' if high_mem else ' '  # formatting high_mem
    
    qos_debug = False  # whether to use QOS queue (debug or not)
    qos_debug_cmd = f' {cyan_color("--qos")}=debug ' if qos_debug else ' '  # formatting qos_debug
    hours = 2 if qos_debug else hours  # decreasing the number of hours for debug mode

    # Print out the sbatch command to run greasy
    print(f"{red_color('sbatch')} {cyan_color('--job-name')}='GREASY_agg_{cell_type}_{method}' "
          f"{cyan_color('--ntasks')}={n_tasks} {cyan_color('--time')}='{hours}:00:00' "
          f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
          f"{cyan_color('--cpus-per-task')}={cpus_per_task}{qos_debug_cmd}{high_mem_cmd}"
          f"{CURR_DIR}/{red_color('greasy_agg_GRN.sh')} {method} {green_color(cell_type)}")
        
    # Generate list of tasks
    tasks = ''
    i = 1
        
    for pat_type in pat_types:
        # TF task
        task_1 = f"{CURR_DIR}/infer_agg_GRN.sh {method} {cell_type} {pat_type} {num_workers_per_task} {Q_THRESH} {_TF_LIST_lambert} GREASY {i}"
        if _PRINT_TASKS_HERE:
            print(task_1)
        tasks += f'{task_1}\n'
        i += 1
    print()
    for pat_type in pat_types:
        # All genes task
        task_2 = f"{CURR_DIR}/infer_agg_GRN.sh {method} {cell_type} {pat_type} {num_workers_per_task} {Q_THRESH} '' GREASY {i}"
        if _PRINT_TASKS_HERE:
            print(task_2)
        i += 1
        tasks += f'{task_2}\n'
        
    if _PRINT_TASKS_HERE:
        print()
        print()

    tasks = tasks.strip()
    with open(f'{_GREASY_DIR}/greasy_tasks_agg_{cell_type}_{method}', 'w') as f:
        f.write(tasks)
# Out:
# sbatch --job-name='GREASY_agg_all_data_grnboost2' --ntasks=4 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=48  --constraint=highmem /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 all_data
#
# sbatch --job-name='GREASY_agg_Macrophage_grnboost2' --ntasks=4 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=48  --constraint=highmem /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Macrophage
#
# sbatch --job-name='GREASY_agg_Monocyte_grnboost2' --ntasks=6 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=32  --constraint=highmem /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Monocyte
#
# sbatch --job-name='GREASY_agg_T_cells_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 T_cells
#
# sbatch --job-name='GREASY_agg_Neutrophils_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Neutrophils
#
# sbatch --job-name='GREASY_agg_DC_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 DC
#
# sbatch --job-name='GREASY_agg_NK_cell_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 NK_cell
#
# sbatch --job-name='GREASY_agg_Epithelial_cells_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Epithelial_cells
#
# sbatch --job-name='GREASY_agg_B_cell_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 B_cell
#
# sbatch --job-name='GREASY_agg_Pre-B_cell_CD34-_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Pre-B_cell_CD34-
#
# sbatch --job-name='GREASY_agg_HSC_-G-CSF_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 HSC_-G-CSF
#
# sbatch --job-name='GREASY_agg_Pro-B_cell_CD34+_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Pro-B_cell_CD34+
#
# sbatch --job-name='GREASY_agg_GMP_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 GMP
#
# sbatch --job-name='GREASY_agg_CMP_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 CMP
#
# sbatch --job-name='GREASY_agg_BM_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 BM
#
# sbatch --job-name='GREASY_agg_Gametocytes_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Gametocytes
#
# sbatch --job-name='GREASY_agg_Erythroblast_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Erythroblast
#
# sbatch --job-name='GREASY_agg_Fibroblasts_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Fibroblasts
#
# sbatch --job-name='GREASY_agg_Neurons_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Neurons
#
# sbatch --job-name='GREASY_agg_Smooth_muscle_cells_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Smooth_muscle_cells
#
# sbatch --job-name='GREASY_agg_Hepatocytes_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Hepatocytes
#
# sbatch --job-name='GREASY_agg_Keratinocytes_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Keratinocytes
#
# sbatch --job-name='GREASY_agg_Pro-Myelocyte_grnboost2' --ntasks=12 --time='48:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=16  /gpfs/home/bsc08/bsc08890/scGRN_analysis/scGRN/network_inference/ana_scripts/greasy_agg_GRN.sh grnboost2 Pro-Myelocyte

# %% [markdown]
# ## COMMUNITY ANALYSIS CELL TYPES AGGREGATED

# %%
cyan_color = lambda x: colored(x, 'cyan')
red_color = lambda x: colored(x, 'red')

algo = 'leiden'
cell_types = ['all_data'] + list(full_meta.columns[3:])
datas = list(map(lambda x: 'raw_data' if x == 'all_data' else f'raw_data_{x}', cell_types))
Q_THRESH = 0.95

display(full_cell_type_dist.sum().sort_values(ascending=False))

i = 1

for d, cell_type in zip(datas, cell_types):    
    n_tasks = len(datas) // 2  # Running only half of tasks in parallel
    cpus_per_task = 24
    hours = 12

    qos_debug = False
    qos_debug_cmd = f' {cyan_color("--qos")}=debug ' if qos_debug else ' '

    print(f"{red_color('sbatch')} {cyan_color('--job-name')}='{cell_type}_community_ana_{algo}' "
          f"{cyan_color('--ntasks')}=1 {cyan_color('--time')}='{hours}:00:00' "
          f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
          f"{cyan_color('--cpus-per-task')}={cpus_per_task}{qos_debug_cmd}{red_color('community_ana_cell_type.sh')} {d} {algo}")
    i += 1
# Out:
# Macrophage             27418.0
# Monocyte               15630.0
# T_cells                 6403.0
# Neutrophils             5638.0
# DC                      1585.0
# NK_cell                 1481.0
# Epithelial_cells        1242.0
# B_cell                   591.0
# Pre-B_cell_CD34-         384.0
# HSC_-G-CSF                61.0
# Pro-B_cell_CD34+          45.0
# GMP                       20.0
# CMP                       16.0
# BM                        14.0
# Gametocytes                4.0
# Erythroblast               2.0
# Fibroblasts                2.0
# Neurons                    1.0
# Smooth_muscle_cells        1.0
# Hepatocytes                1.0
# Keratinocytes              1.0
# Pro-Myelocyte              1.0
# dtype: float64
# sbatch --job-name='all_data_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data leiden
# sbatch --job-name='Macrophage_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Macrophage leiden
# sbatch --job-name='T_cells_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_T_cells leiden
# sbatch --job-name='DC_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_DC leiden
# sbatch --job-name='Pre-B_cell_CD34-_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Pre-B_cell_CD34- leiden
# sbatch --job-name='Monocyte_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Monocyte leiden
# sbatch --job-name='NK_cell_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_NK_cell leiden
# sbatch --job-name='B_cell_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_B_cell leiden
# sbatch --job-name='Epithelial_cells_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Epithelial_cells leiden
# sbatch --job-name='BM_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_BM leiden
# sbatch --job-name='Pro-B_cell_CD34+_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Pro-B_cell_CD34+ leiden
# sbatch --job-name='HSC_-G-CSF_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_HSC_-G-CSF leiden
# sbatch --job-name='Neutrophils_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Neutrophils leiden
# sbatch --job-name='CMP_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_CMP leiden
# sbatch --job-name='GMP_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_GMP leiden
# sbatch --job-name='Gametocytes_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Gametocytes leiden
# sbatch --job-name='Erythroblast_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Erythroblast leiden
# sbatch --job-name='Neurons_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Neurons leiden
# sbatch --job-name='Fibroblasts_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Fibroblasts leiden
# sbatch --job-name='Smooth_muscle_cells_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Smooth_muscle_cells leiden
# sbatch --job-name='Hepatocytes_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Hepatocytes leiden
# sbatch --job-name='Keratinocytes_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Keratinocytes leiden
# sbatch --job-name='Pro-Myelocyte_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana_cell_type.sh raw_data_Pro-Myelocyte leiden

# %% [markdown]
# ## COMMUNITY ANALYSIS CELL TYPES (ONE PATIENT TYPE) AGGREGATED

# %%
cyan_color = lambda x: colored(x, 'cyan')
red_color = lambda x: colored(x, 'red')

method = 'leiden'
cell_types = ['all_data', 'Macrophage', 'T_cells', 'DC', 'Monocyte', 'NK_cell', 'B_cell', 'Epithelial_cells', 'Neutrophils', 'Pre-B_cell_CD34-']
datas = list(map(lambda x: 'raw_data' if x == 'all_data' else f'raw_data_{x}', cell_types))
Q_THRESH = 0.95

display(full_cell_type_dist.sum().sort_values(ascending=False)[cell_types[1:]])

i = 1

for d, cell_type in zip(datas, cell_types):   
    for t in ['C', 'M', 'S']:
        n_tasks = len(datas) // 2  # Running only half of tasks in parallel
        cpus_per_task = 24
        hours = 12

        qos_debug = False
        qos_debug_cmd = f' {cyan_color("--qos")}=debug ' if qos_debug else ' '

        print(f"{red_color('sbatch')} {cyan_color('--job-name')}='{cell_type}_{t}_type_community_ana_{algo}' "
              f"{cyan_color('--ntasks')}=1 {cyan_color('--time')}='{hours}:00:00' "
              f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
              f"{cyan_color('--cpus-per-task')}={cpus_per_task}{qos_debug_cmd}{red_color('community_ana.sh')} {t} {d} {algo}")
        i += 1
# Out:
# Macrophage          27418.0
# T_cells              6403.0
# DC                   1585.0
# Monocyte            15630.0
# NK_cell              1481.0
# B_cell                591.0
# Epithelial_cells     1242.0
# Neutrophils          5638.0
# Pre-B_cell_CD34-      384.0
# dtype: float64
# sbatch --job-name='all_data_C_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh C raw_data leiden
# sbatch --job-name='all_data_M_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh M raw_data leiden
# sbatch --job-name='all_data_S_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh S raw_data leiden
# sbatch --job-name='Macrophage_C_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh C raw_data_Macrophage leiden
# sbatch --job-name='Macrophage_M_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh M raw_data_Macrophage leiden
# sbatch --job-name='Macrophage_S_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh S raw_data_Macrophage leiden
# sbatch --job-name='T_cells_C_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh C raw_data_T_cells leiden
# sbatch --job-name='T_cells_M_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh M raw_data_T_cells leiden
# sbatch --job-name='T_cells_S_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh S raw_data_T_cells leiden
# sbatch --job-name='DC_C_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh C raw_data_DC leiden
# sbatch --job-name='DC_M_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh M raw_data_DC leiden
# sbatch --job-name='DC_S_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh S raw_data_DC leiden
# sbatch --job-name='Monocyte_C_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh C raw_data_Monocyte leiden
# sbatch --job-name='Monocyte_M_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh M raw_data_Monocyte leiden
# sbatch --job-name='Monocyte_S_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh S raw_data_Monocyte leiden
# sbatch --job-name='NK_cell_C_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh C raw_data_NK_cell leiden
# sbatch --job-name='NK_cell_M_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh M raw_data_NK_cell leiden
# sbatch --job-name='NK_cell_S_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh S raw_data_NK_cell leiden
# sbatch --job-name='B_cell_C_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh C raw_data_B_cell leiden
# sbatch --job-name='B_cell_M_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh M raw_data_B_cell leiden
# sbatch --job-name='B_cell_S_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh S raw_data_B_cell leiden
# sbatch --job-name='Epithelial_cells_C_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh C raw_data_Epithelial_cells leiden
# sbatch --job-name='Epithelial_cells_M_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh M raw_data_Epithelial_cells leiden
# sbatch --job-name='Epithelial_cells_S_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh S raw_data_Epithelial_cells leiden
# sbatch --job-name='Neutrophils_C_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh C raw_data_Neutrophils leiden
# sbatch --job-name='Neutrophils_M_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh M raw_data_Neutrophils leiden
# sbatch --job-name='Neutrophils_S_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh S raw_data_Neutrophils leiden
# sbatch --job-name='Pre-B_cell_CD34-_C_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh C raw_data_Pre-B_cell_CD34- leiden
# sbatch --job-name='Pre-B_cell_CD34-_M_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh M raw_data_Pre-B_cell_CD34- leiden
# sbatch --job-name='Pre-B_cell_CD34-_S_type_community_ana_leiden' --ntasks=1 --time='12:00:00' --output=/dev/null --error=/dev/null --cpus-per-task=24 community_ana.sh S raw_data_Pre-B_cell_CD34- leiden

# %% [markdown]
# ##### COMMUNITY ANALYSIS

# %%
cyan_color = lambda x: colored(x, 'cyan')
red_color = lambda x: colored(x, 'red')

# Patients - 'C141', 'C142', 'C143', 'C144', 'C145', 'C146', 'C51', 'C52', 'C100', 'C148', 'C149', 'C152'

for patient in ['C141', 'C142', 'C143', 'C144', 'C145', 'C146', 'C51', 'C52', 'C100', 'C148', 'C149', 'C152']:
    # patient = 'C152'
    algo = 'leiden'
    datas = _ALL_FILE_PREFIXES[patient]
    cell_type_x = full_meta.loc[patient].drop(['file', 'group']).dropna()

    n_tasks = len(datas) // 2  # Running only half of tasks in parallel
    cpus_per_task = 48
    hours = 24
    num_workers_per_task = cpus_per_task // 3

    qos_debug = False
    qos_debug_cmd = f' {cyan_color("--qos")}=debug ' if qos_debug else ' '

    # display(pd.DataFrame(cell_type_x).T)

    print(f"{red_color('sbatch')} {cyan_color('--job-name')}='{patient}_GREASY_community_ana_{algo}' "
          f"{cyan_color('--ntasks')}={n_tasks} {cyan_color('--time')}='{hours}:00:00' "
          f"{cyan_color('--output')}=/dev/null {cyan_color('--error')}=/dev/null "
          f"{cyan_color('--cpus-per-task')}={cpus_per_task}{qos_debug_cmd}{red_color('greasy_community_ana.sh')} {patient} {algo}")

    tasks = ''
    print()
    i = 1
    for d in datas:
        task = f"../community_ana.sh {patient} {d} {algo} GREASY {i}"
        # print(task)
        i += 1
        tasks += f'{task}\n'

    tasks = tasks.strip()
    with open(f'/gpfs/projects/bsc08/bsc08890/sbatch/greasy/greasy_tasks_community_ana_{patient}_{algo}', 'w') as f:
        f.write(tasks)

# %% [markdown]
# ### Report of available data
#
# Below we report the networks that were inferred. The user should pay attention to "?" cells (in red) - these cells correspond to networks where GRN inference pipeline was **failed**.

# %%
# Getting adjacency list/NetworkX object availability matrices
_AVAIL_ADJ_LISTs = scGRN.ana.get_avail_adj_lists(
    data_home=_DATA_HOME,
    meta_file=_FMETA
)
_AVAIL_Gs = scGRN.ana.get_avail_nx_graphs(
    data_home=_DATA_HOME,
    meta_file=_FMETA
)

# Visualizing the GRN availability matrix
for net_type in _NET_TYPES:
    print(f"{colored(net_type, 'cyan')}-type networks")
    display(scGRN.util.style_bool_df(_AVAIL_Gs[net_type]))

# Printing the legend
check, missing, cross = u'\u2713', '?', u'\u2715'  # green, red, yellow
print(colored('Legend:', 'green'))
print('all_data: The aggregated data, e.g. ("all_data", "Macrophage") - all macrophages, ("C152", "all_data") - all cells from C152.')
print(f'{check}: Data is processed and ready for use')
print(f'{missing}: Failed to detect the data file, although the corresponding cell type is present in patient')
print(f'{cross}: The corresponding cell type is not present in patient')
# Out:
# all-type networks
# <style type="text/css">
# #T_22278_row0_col0, #T_22278_row0_col9, #T_22278_row0_col10, #T_22278_row0_col11, #T_22278_row0_col12, #T_22278_row0_col14, #T_22278_row0_col15, #T_22278_row0_col16, #T_22278_row0_col17, #T_22278_row0_col18, #T_22278_row0_col19, #T_22278_row0_col20, #T_22278_row0_col21, #T_22278_row0_col22, #T_22278_row1_col9, #T_22278_row1_col10, #T_22278_row1_col11, #T_22278_row1_col12, #T_22278_row2_col9, #T_22278_row2_col10, #T_22278_row2_col11, #T_22278_row2_col12, #T_22278_row2_col14, #T_22278_row2_col15, #T_22278_row3_col0, #T_22278_row3_col9, #T_22278_row3_col10, #T_22278_row3_col11, #T_22278_row3_col12, #T_22278_row3_col14, #T_22278_row3_col16, #T_22278_row3_col17, #T_22278_row3_col18, #T_22278_row3_col19, #T_22278_row3_col20, #T_22278_row3_col21, #T_22278_row3_col22 {
#   background-color: red;
# }
# #T_22278_row0_col1, #T_22278_row0_col2, #T_22278_row0_col3, #T_22278_row0_col4, #T_22278_row0_col5, #T_22278_row0_col6, #T_22278_row0_col7, #T_22278_row0_col8, #T_22278_row0_col13, #T_22278_row1_col0, #T_22278_row1_col1, #T_22278_row1_col2, #T_22278_row1_col3, #T_22278_row1_col4, #T_22278_row1_col5, #T_22278_row1_col6, #T_22278_row1_col7, #T_22278_row1_col8, #T_22278_row2_col0, #T_22278_row2_col1, #T_22278_row2_col2, #T_22278_row2_col3, #T_22278_row2_col4, #T_22278_row2_col5, #T_22278_row2_col6, #T_22278_row2_col7, #T_22278_row2_col8, #T_22278_row2_col13, #T_22278_row3_col1, #T_22278_row3_col2, #T_22278_row3_col3, #T_22278_row3_col4, #T_22278_row3_col5, #T_22278_row3_col6, #T_22278_row3_col7, #T_22278_row3_col8, #T_22278_row3_col13, #T_22278_row4_col0, #T_22278_row4_col1, #T_22278_row4_col2, #T_22278_row4_col3, #T_22278_row4_col4, #T_22278_row4_col5, #T_22278_row4_col6, #T_22278_row4_col7, #T_22278_row4_col8, #T_22278_row4_col9, #T_22278_row4_col10, #T_22278_row4_col11, #T_22278_row5_col0, #T_22278_row5_col1, #T_22278_row5_col2, #T_22278_row5_col3, #T_22278_row5_col4, #T_22278_row5_col5, #T_22278_row5_col6, #T_22278_row5_col7, #T_22278_row5_col8, #T_22278_row6_col0, #T_22278_row6_col1, #T_22278_row6_col2, #T_22278_row6_col3, #T_22278_row6_col4, #T_22278_row6_col5, #T_22278_row6_col6, #T_22278_row6_col7, #T_22278_row6_col8, #T_22278_row6_col10, #T_22278_row6_col12, #T_22278_row7_col0, #T_22278_row7_col1, #T_22278_row7_col2, #T_22278_row7_col3, #T_22278_row7_col4, #T_22278_row7_col5, #T_22278_row7_col6, #T_22278_row7_col7, #T_22278_row7_col8, #T_22278_row7_col12, #T_22278_row7_col13, #T_22278_row7_col14, #T_22278_row8_col0, #T_22278_row8_col1, #T_22278_row8_col2, #T_22278_row8_col3, #T_22278_row8_col4, #T_22278_row8_col5, #T_22278_row8_col6, #T_22278_row8_col7, #T_22278_row8_col8, #T_22278_row8_col9, #T_22278_row8_col10, #T_22278_row8_col11, #T_22278_row8_col12, #T_22278_row8_col13, #T_22278_row8_col14, #T_22278_row9_col0, #T_22278_row9_col1, #T_22278_row9_col2, #T_22278_row9_col3, #T_22278_row9_col4, #T_22278_row9_col5, #T_22278_row9_col6, #T_22278_row9_col7, #T_22278_row9_col8, #T_22278_row9_col9, #T_22278_row9_col10, #T_22278_row9_col11, #T_22278_row9_col12, #T_22278_row9_col13, #T_22278_row9_col15, #T_22278_row10_col0, #T_22278_row10_col1, #T_22278_row10_col2, #T_22278_row10_col3, #T_22278_row10_col4, #T_22278_row10_col5, #T_22278_row10_col6, #T_22278_row10_col7, #T_22278_row10_col8, #T_22278_row10_col10, #T_22278_row10_col11, #T_22278_row10_col12, #T_22278_row10_col13, #T_22278_row10_col14, #T_22278_row10_col16, #T_22278_row10_col17, #T_22278_row11_col0, #T_22278_row11_col1, #T_22278_row11_col2, #T_22278_row11_col3, #T_22278_row11_col4, #T_22278_row11_col5, #T_22278_row11_col6, #T_22278_row11_col7, #T_22278_row11_col8, #T_22278_row11_col10, #T_22278_row11_col11, #T_22278_row11_col13, #T_22278_row11_col14, #T_22278_row12_col0, #T_22278_row12_col1, #T_22278_row12_col2, #T_22278_row12_col3, #T_22278_row12_col5, #T_22278_row12_col6, #T_22278_row12_col7, #T_22278_row12_col8, #T_22278_row12_col11, #T_22278_row12_col13, #T_22278_row12_col16, #T_22278_row12_col18, #T_22278_row12_col19, #T_22278_row12_col20, #T_22278_row12_col21, #T_22278_row13_col0, #T_22278_row13_col1, #T_22278_row13_col2, #T_22278_row13_col3, #T_22278_row13_col5, #T_22278_row13_col6, #T_22278_row13_col7, #T_22278_row13_col8, #T_22278_row13_col10, #T_22278_row13_col12, #T_22278_row13_col13, #T_22278_row13_col14, #T_22278_row13_col16, #T_22278_row14_col0, #T_22278_row14_col1, #T_22278_row14_col2, #T_22278_row14_col3, #T_22278_row14_col4, #T_22278_row14_col5, #T_22278_row14_col6, #T_22278_row14_col7, #T_22278_row14_col8, #T_22278_row14_col11, #T_22278_row14_col13, #T_22278_row15_col0, #T_22278_row15_col1, #T_22278_row15_col2, #T_22278_row15_col3, #T_22278_row15_col4, #T_22278_row15_col5, #T_22278_row15_col6, #T_22278_row15_col7, #T_22278_row15_col8, #T_22278_row15_col9, #T_22278_row15_col10, #T_22278_row15_col13, #T_22278_row15_col14, #T_22278_row15_col22 {
#   background-color: green;
# }
# #T_22278_row1_col13, #T_22278_row1_col14, #T_22278_row1_col15, #T_22278_row1_col16, #T_22278_row1_col17, #T_22278_row1_col18, #T_22278_row1_col19, #T_22278_row1_col20, #T_22278_row1_col21, #T_22278_row1_col22, #T_22278_row2_col16, #T_22278_row2_col17, #T_22278_row2_col18, #T_22278_row2_col19, #T_22278_row2_col20, #T_22278_row2_col21, #T_22278_row2_col22, #T_22278_row3_col15, #T_22278_row4_col12, #T_22278_row4_col13, #T_22278_row4_col14, #T_22278_row4_col15, #T_22278_row4_col16, #T_22278_row4_col17, #T_22278_row4_col18, #T_22278_row4_col19, #T_22278_row4_col20, #T_22278_row4_col21, #T_22278_row4_col22, #T_22278_row5_col9, #T_22278_row5_col10, #T_22278_row5_col11, #T_22278_row5_col12, #T_22278_row5_col13, #T_22278_row5_col14, #T_22278_row5_col15, #T_22278_row5_col16, #T_22278_row5_col17, #T_22278_row5_col18, #T_22278_row5_col19, #T_22278_row5_col20, #T_22278_row5_col21, #T_22278_row5_col22, #T_22278_row6_col9, #T_22278_row6_col11, #T_22278_row6_col13, #T_22278_row6_col14, #T_22278_row6_col15, #T_22278_row6_col16, #T_22278_row6_col17, #T_22278_row6_col18, #T_22278_row6_col19, #T_22278_row6_col20, #T_22278_row6_col21, #T_22278_row6_col22, #T_22278_row7_col9, #T_22278_row7_col10, #T_22278_row7_col11, #T_22278_row7_col15, #T_22278_row7_col16, #T_22278_row7_col17, #T_22278_row7_col18, #T_22278_row7_col19, #T_22278_row7_col20, #T_22278_row7_col21, #T_22278_row7_col22, #T_22278_row8_col15, #T_22278_row8_col16, #T_22278_row8_col17, #T_22278_row8_col18, #T_22278_row8_col19, #T_22278_row8_col20, #T_22278_row8_col21, #T_22278_row8_col22, #T_22278_row9_col14, #T_22278_row9_col16, #T_22278_row9_col17, #T_22278_row9_col18, #T_22278_row9_col19, #T_22278_row9_col20, #T_22278_row9_col21, #T_22278_row9_col22, #T_22278_row10_col9, #T_22278_row10_col15, #T_22278_row10_col18, #T_22278_row10_col19, #T_22278_row10_col20, #T_22278_row10_col21, #T_22278_row10_col22, #T_22278_row11_col9, #T_22278_row11_col12, #T_22278_row11_col15, #T_22278_row11_col16, #T_22278_row11_col17, #T_22278_row11_col18, #T_22278_row11_col19, #T_22278_row11_col20, #T_22278_row11_col21, #T_22278_row11_col22, #T_22278_row12_col4, #T_22278_row12_col9, #T_22278_row12_col10, #T_22278_row12_col12, #T_22278_row12_col14, #T_22278_row12_col15, #T_22278_row12_col17, #T_22278_row12_col22, #T_22278_row13_col4, #T_22278_row13_col9, #T_22278_row13_col11, #T_22278_row13_col15, #T_22278_row13_col17, #T_22278_row13_col18, #T_22278_row13_col19, #T_22278_row13_col20, #T_22278_row13_col21, #T_22278_row13_col22, #T_22278_row14_col9, #T_22278_row14_col10, #T_22278_row14_col12, #T_22278_row14_col14, #T_22278_row14_col15, #T_22278_row14_col16, #T_22278_row14_col17, #T_22278_row14_col18, #T_22278_row14_col19, #T_22278_row14_col20, #T_22278_row14_col21, #T_22278_row14_col22, #T_22278_row15_col11, #T_22278_row15_col12, #T_22278_row15_col15, #T_22278_row15_col16, #T_22278_row15_col17, #T_22278_row15_col18, #T_22278_row15_col19, #T_22278_row15_col20, #T_22278_row15_col21 {
#   background-color: yellow;
# }
# </style>
# <table id="T_22278_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >all_data</th>
#       <th class="col_heading l
# TF-type networks
# <style type="text/css">
# #T_3c1b2_row0_col0, #T_3c1b2_row0_col1, #T_3c1b2_row0_col2, #T_3c1b2_row0_col3, #T_3c1b2_row0_col4, #T_3c1b2_row0_col5, #T_3c1b2_row0_col6, #T_3c1b2_row0_col7, #T_3c1b2_row0_col8, #T_3c1b2_row0_col13, #T_3c1b2_row1_col0, #T_3c1b2_row1_col1, #T_3c1b2_row1_col2, #T_3c1b2_row1_col3, #T_3c1b2_row1_col4, #T_3c1b2_row1_col5, #T_3c1b2_row1_col6, #T_3c1b2_row1_col7, #T_3c1b2_row1_col8, #T_3c1b2_row2_col0, #T_3c1b2_row2_col1, #T_3c1b2_row2_col2, #T_3c1b2_row2_col3, #T_3c1b2_row2_col4, #T_3c1b2_row2_col5, #T_3c1b2_row2_col6, #T_3c1b2_row2_col7, #T_3c1b2_row2_col8, #T_3c1b2_row2_col13, #T_3c1b2_row3_col0, #T_3c1b2_row3_col1, #T_3c1b2_row3_col2, #T_3c1b2_row3_col3, #T_3c1b2_row3_col4, #T_3c1b2_row3_col5, #T_3c1b2_row3_col6, #T_3c1b2_row3_col7, #T_3c1b2_row3_col8, #T_3c1b2_row3_col13, #T_3c1b2_row4_col0, #T_3c1b2_row4_col1, #T_3c1b2_row4_col2, #T_3c1b2_row4_col3, #T_3c1b2_row4_col4, #T_3c1b2_row4_col5, #T_3c1b2_row4_col6, #T_3c1b2_row4_col7, #T_3c1b2_row4_col8, #T_3c1b2_row4_col9, #T_3c1b2_row4_col10, #T_3c1b2_row4_col11, #T_3c1b2_row5_col0, #T_3c1b2_row5_col1, #T_3c1b2_row5_col2, #T_3c1b2_row5_col3, #T_3c1b2_row5_col4, #T_3c1b2_row5_col5, #T_3c1b2_row5_col6, #T_3c1b2_row5_col7, #T_3c1b2_row5_col8, #T_3c1b2_row6_col0, #T_3c1b2_row6_col1, #T_3c1b2_row6_col2, #T_3c1b2_row6_col3, #T_3c1b2_row6_col4, #T_3c1b2_row6_col5, #T_3c1b2_row6_col6, #T_3c1b2_row6_col7, #T_3c1b2_row6_col8, #T_3c1b2_row6_col10, #T_3c1b2_row6_col12, #T_3c1b2_row7_col0, #T_3c1b2_row7_col1, #T_3c1b2_row7_col2, #T_3c1b2_row7_col3, #T_3c1b2_row7_col4, #T_3c1b2_row7_col5, #T_3c1b2_row7_col6, #T_3c1b2_row7_col7, #T_3c1b2_row7_col8, #T_3c1b2_row7_col12, #T_3c1b2_row7_col13, #T_3c1b2_row7_col14, #T_3c1b2_row8_col0, #T_3c1b2_row8_col1, #T_3c1b2_row8_col2, #T_3c1b2_row8_col3, #T_3c1b2_row8_col4, #T_3c1b2_row8_col5, #T_3c1b2_row8_col6, #T_3c1b2_row8_col7, #T_3c1b2_row8_col8, #T_3c1b2_row8_col9, #T_3c1b2_row8_col10, #T_3c1b2_row8_col11, #T_3c1b2_row8_col12, #T_3c1b2_row8_col13, #T_3c1b2_row8_col14, #T_3c1b2_row9_col0, #T_3c1b2_row9_col1, #T_3c1b2_row9_col2, #T_3c1b2_row9_col3, #T_3c1b2_row9_col4, #T_3c1b2_row9_col5, #T_3c1b2_row9_col6, #T_3c1b2_row9_col7, #T_3c1b2_row9_col8, #T_3c1b2_row9_col9, #T_3c1b2_row9_col10, #T_3c1b2_row9_col11, #T_3c1b2_row9_col12, #T_3c1b2_row9_col13, #T_3c1b2_row9_col15, #T_3c1b2_row10_col0, #T_3c1b2_row10_col1, #T_3c1b2_row10_col2, #T_3c1b2_row10_col3, #T_3c1b2_row10_col4, #T_3c1b2_row10_col5, #T_3c1b2_row10_col6, #T_3c1b2_row10_col7, #T_3c1b2_row10_col8, #T_3c1b2_row10_col10, #T_3c1b2_row10_col11, #T_3c1b2_row10_col12, #T_3c1b2_row10_col13, #T_3c1b2_row10_col14, #T_3c1b2_row10_col16, #T_3c1b2_row10_col17, #T_3c1b2_row11_col0, #T_3c1b2_row11_col1, #T_3c1b2_row11_col2, #T_3c1b2_row11_col3, #T_3c1b2_row11_col4, #T_3c1b2_row11_col5, #T_3c1b2_row11_col6, #T_3c1b2_row11_col7, #T_3c1b2_row11_col8, #T_3c1b2_row11_col10, #T_3c1b2_row11_col11, #T_3c1b2_row11_col13, #T_3c1b2_row11_col14, #T_3c1b2_row12_col0, #T_3c1b2_row12_col1, #T_3c1b2_row12_col2, #T_3c1b2_row12_col3, #T_3c1b2_row12_col5, #T_3c1b2_row12_col6, #T_3c1b2_row12_col7, #T_3c1b2_row12_col8, #T_3c1b2_row12_col11, #T_3c1b2_row12_col13, #T_3c1b2_row12_col16, #T_3c1b2_row12_col18, #T_3c1b2_row12_col19, #T_3c1b2_row12_col20, #T_3c1b2_row12_col21, #T_3c1b2_row13_col0, #T_3c1b2_row13_col1, #T_3c1b2_row13_col2, #T_3c1b2_row13_col3, #T_3c1b2_row13_col5, #T_3c1b2_row13_col6, #T_3c1b2_row13_col7, #T_3c1b2_row13_col8, #T_3c1b2_row13_col10, #T_3c1b2_row13_col12, #T_3c1b2_row13_col13, #T_3c1b2_row13_col14, #T_3c1b2_row13_col16, #T_3c1b2_row14_col0, #T_3c1b2_row14_col1, #T_3c1b2_row14_col2, #T_3c1b2_row14_col3, #T_3c1b2_row14_col4, #T_3c1b2_row14_col5, #T_3c1b2_row14_col6, #T_3c1b2_row14_col7, #T_3c1b2_row14_col8, #T_3c1b2_row14_col11, #T_3c1b2_row14_col13, #T_3c1b2_row15_col0, #T_3c1b2_row15_col1, #T_3c1b2_row15_col2, #T_3c1b2_row15_col3, #T_3c1b2_row15_col4, #T_3c1b2_row15_col5, #T_3c1b2_row15_col6, #T_3c1b2_row15_col7, #T_3c1b2_row15_col8, #T_3c1b2_row15_col9, #T_3c1b2_row15_col10, #T_3c1b2_row15_col13, #T_3c1b2_row1 ...
#   background-color: green;
# }
# #T_3c1b2_row0_col9, #T_3c1b2_row0_col10, #T_3c1b2_row0_col11, #T_3c1b2_row0_col12, #T_3c1b2_row0_col14, #T_3c1b2_row0_col15, #T_3c1b2_row0_col16, #T_3c1b2_row0_col17, #T_3c1b2_row0_col18, #T_3c1b2_row0_col19, #T_3c1b2_row0_col20, #T_3c1b2_row0_col21, #T_3c1b2_row0_col22, #T_3c1b2_row1_col9, #T_3c1b2_row1_col10, #T_3c1b2_row1_col11, #T_3c1b2_row1_col12, #T_3c1b2_row2_col9, #T_3c1b2_row2_col10, #T_3c1b2_row2_col11, #T_3c1b2_row2_col12, #T_3c1b2_row2_col14, #T_3c1b2_row2_col15, #T_3c1b2_row3_col9, #T_3c1b2_row3_col10, #T_3c1b2_row3_col11, #T_3c1b2_row3_col12, #T_3c1b2_row3_col14, #T_3c1b2_row3_col16, #T_3c1b2_row3_col17, #T_3c1b2_row3_col18, #T_3c1b2_row3_col19, #T_3c1b2_row3_col20, #T_3c1b2_row3_col21, #T_3c1b2_row3_col22 {
#   background-color: red;
# }
# #T_3c1b2_row1_col13, #T_3c1b2_row1_col14, #T_3c1b2_row1_col15, #T_3c1b2_row1_col16, #T_3c1b2_row1_col17, #T_3c1b2_row1_col18, #T_3c1b2_row1_col19, #T_3c1b2_row1_col20, #T_3c1b2_row1_col21, #T_3c1b2_row1_col22, #T_3c1b2_row2_col16, #T_3c1b2_row2_col17, #T_3c1b2_row2_col18, #T_3c1b2_row2_col19, #T_3c1b2_row2_col20, #T_3c1b2_row2_col21, #T_3c1b2_row2_col22, #T_3c1b2_row3_col15, #T_3c1b2_row4_col12, #T_3c1b2_row4_col13, #T_3c1b2_row4_col14, #T_3c1b2_row4_col15, #T_3c1b2_row4_col16, #T_3c1b2_row4_col17, #T_3c1b2_row4_col18, #T_3c1b2_row4_col19, #T_3c1b2_row4_col20, #T_3c1b2_row4_col21, #T_3c1b2_row4_col22, #T_3c1b2_row5_col9, #T_3c1b2_row5_col10, #T_3c1b2_row5_col11, #T_3c1b2_row5_col12, #T_3c1b2_row5_col13, #T_3c1b2_row5_col14, #T_3c1b2_row5_col15, #T_3c1b2_row5_col16, #T_3c1b2_row5_col17, #T_3c1b2_row5_col18, #T_3c1b2_row5_col19, #T_3c1b2_row5_col20, #T_3c1b2_row5_col21, #T_3c1b2_row5_col22, #T_3c1b2_row6_col9, #T_3c1b2_row6_col11, #T_3c1b2_row6_col13, #T_3c1b2_row6_col14, #T_3c1b2_row6_col15, #T_3c1b2_row6_col16, #T_3c1b2_row6_col17, #T_3c1b2_row6_col18, #T_3c1b2_row6_col19, #T_3c1b2_row6_col20, #T_3c1b2_row6_col21, #T_3c1b2_row6_col22, #T_3c1b2_row7_col9, #T_3c1b2_row7_col10, #T_3c1b2_row7_col11, #T_3c1b2_row7_col15, #T_3c1b2_row7_col16, #T_3c1b2_row7_col17, #T_3c1b2_row7_col18, #T_3c1b2_row7_col19, #T_3c1b2_row7_col20, #T_3c1b2_row7_col21, #T_3c1b2_row7_col22, #T_3c1b2_row8_col15, #T_3c1b2_row8_col16, #T_3c1b2_row8_col17, #T_3c1b2_row8_col18, #T_3c1b2_row8_col19, #T_3c1b2_row8_col20, #T_3c1b2_row8_col21, #T_3c1b2_row8_col22, #T_3c1b2_row9_col14, #T_3c1b2_row9_col16, #T_3c1b2_row9_col17, #T_3c1b2_row9_col18, #T_3c1b2_row9_col19, #T_3c1b2_row9_col20, #T_3c1b2_row9_col21, #T_3c1b2_row9_col22, #T_3c1b2_row10_col9, #T_3c1b2_row10_col15, #T_3c1b2_row10_col18, #T_3c1b2_row10_col19, #T_3c1b2_row10_col20, #T_3c1b2_row10_col21, #T_3c1b2_row10_col22, #T_3c1b2_row11_col9, #T_3c1b2_row11_col12, #T_3c1b2_row11_col15, #T_3c1b2_row11_col16, #T_3c1b2_row11_col17, #T_3c1b2_row11_col18, #T_3c1b2_row11_col19, #T_3c1b2_row11_col20, #T_3c1b2_row11_col21, #T_3c1b2_row11_col22, #T_3c1b2_row12_col4, #T_3c1b2_row12_col9, #T_3c1b2_row12_col10, #T_3c1b2_row12_col12, #T_3c1b2_row12_col14, #T_3c1b2_row12_col15, #T_3c1b2_row12_col17, #T_3c1b2_row12_col22, #T_3c1b2_row13_col4, #T_3c1b2_row13_col9, #T_3c1b2_row13_col11, #T_3c1b2_row13_col15, #T_3c1b2_row13_col17, #T_3c1b2_row13_col18, #T_3c1b2_row13_col19, #T_3c1b2_row13_col20, #T_3c1b2_row13_col21, #T_3c1b2_row13_col22, #T_3c1b2_row14_col9, #T_3c1b2_row14_col10, #T_3c1b2_row14_col12, #T_3c1b2_row14_col14, #T_3c1b2_row14_col15, #T_3c1b2_row14_col16, #T_3c1b2_row14_col17, #T_3c1b2_row14_col18, #T_3c1b2_row14_col19, #T_3c1b2_row14_col20, #T_3c1b2_row14_col21, #T_3c1b2_row14_col22, #T_3c1b2_row15_col11, #T_3c1b2_row15_col12, #T_3c1b2_row15_col15, #T_3c1b2_row15_col16, #T_3c1b2_row15_col17, #T_3c1b2_row15_col18, #T_3c1b2_row15_col19, #T_3c1b2_row15_col20, #T_3c1b2_row15_col21 {
#   background-color: yellow;
# }
# </style>
# <table id="T_3c1b2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >all_data</th>
#       <th class="col_heading l
# ctx-type networks
# <style type="text/css">
# #T_1edd4_row0_col0, #T_1edd4_row0_col1, #T_1edd4_row0_col2, #T_1edd4_row0_col3, #T_1edd4_row0_col4, #T_1edd4_row0_col5, #T_1edd4_row0_col6, #T_1edd4_row0_col7, #T_1edd4_row0_col8, #T_1edd4_row0_col13, #T_1edd4_row1_col0, #T_1edd4_row1_col1, #T_1edd4_row1_col2, #T_1edd4_row1_col3, #T_1edd4_row1_col4, #T_1edd4_row1_col5, #T_1edd4_row1_col6, #T_1edd4_row1_col7, #T_1edd4_row1_col8, #T_1edd4_row2_col0, #T_1edd4_row2_col1, #T_1edd4_row2_col2, #T_1edd4_row2_col3, #T_1edd4_row2_col4, #T_1edd4_row2_col5, #T_1edd4_row2_col6, #T_1edd4_row2_col7, #T_1edd4_row2_col8, #T_1edd4_row2_col13, #T_1edd4_row3_col0, #T_1edd4_row3_col1, #T_1edd4_row3_col2, #T_1edd4_row3_col3, #T_1edd4_row3_col4, #T_1edd4_row3_col5, #T_1edd4_row3_col6, #T_1edd4_row3_col7, #T_1edd4_row3_col8, #T_1edd4_row3_col13, #T_1edd4_row4_col0, #T_1edd4_row4_col1, #T_1edd4_row4_col2, #T_1edd4_row4_col3, #T_1edd4_row4_col4, #T_1edd4_row4_col5, #T_1edd4_row4_col6, #T_1edd4_row4_col7, #T_1edd4_row4_col8, #T_1edd4_row4_col9, #T_1edd4_row4_col10, #T_1edd4_row5_col0, #T_1edd4_row5_col1, #T_1edd4_row5_col2, #T_1edd4_row5_col3, #T_1edd4_row5_col4, #T_1edd4_row5_col5, #T_1edd4_row5_col6, #T_1edd4_row5_col8, #T_1edd4_row6_col0, #T_1edd4_row6_col1, #T_1edd4_row6_col2, #T_1edd4_row6_col3, #T_1edd4_row6_col4, #T_1edd4_row6_col5, #T_1edd4_row6_col6, #T_1edd4_row6_col7, #T_1edd4_row6_col8, #T_1edd4_row6_col12, #T_1edd4_row7_col0, #T_1edd4_row7_col1, #T_1edd4_row7_col2, #T_1edd4_row7_col3, #T_1edd4_row7_col4, #T_1edd4_row7_col5, #T_1edd4_row7_col6, #T_1edd4_row7_col7, #T_1edd4_row7_col8, #T_1edd4_row7_col12, #T_1edd4_row7_col13, #T_1edd4_row8_col0, #T_1edd4_row8_col1, #T_1edd4_row8_col2, #T_1edd4_row8_col3, #T_1edd4_row8_col4, #T_1edd4_row8_col5, #T_1edd4_row8_col6, #T_1edd4_row8_col7, #T_1edd4_row8_col8, #T_1edd4_row8_col12, #T_1edd4_row8_col13, #T_1edd4_row9_col0, #T_1edd4_row9_col1, #T_1edd4_row9_col2, #T_1edd4_row9_col3, #T_1edd4_row9_col4, #T_1edd4_row9_col5, #T_1edd4_row9_col6, #T_1edd4_row9_col7, #T_1edd4_row9_col8, #T_1edd4_row9_col13, #T_1edd4_row10_col0, #T_1edd4_row10_col1, #T_1edd4_row10_col2, #T_1edd4_row10_col3, #T_1edd4_row10_col4, #T_1edd4_row10_col5, #T_1edd4_row10_col6, #T_1edd4_row10_col7, #T_1edd4_row10_col8, #T_1edd4_row10_col11, #T_1edd4_row10_col13, #T_1edd4_row11_col0, #T_1edd4_row11_col1, #T_1edd4_row11_col2, #T_1edd4_row11_col3, #T_1edd4_row11_col4, #T_1edd4_row11_col5, #T_1edd4_row11_col6, #T_1edd4_row11_col7, #T_1edd4_row11_col8, #T_1edd4_row11_col11, #T_1edd4_row11_col13, #T_1edd4_row12_col0, #T_1edd4_row12_col1, #T_1edd4_row12_col2, #T_1edd4_row12_col3, #T_1edd4_row12_col5, #T_1edd4_row12_col6, #T_1edd4_row12_col7, #T_1edd4_row12_col8, #T_1edd4_row12_col13, #T_1edd4_row13_col0, #T_1edd4_row13_col1, #T_1edd4_row13_col2, #T_1edd4_row13_col3, #T_1edd4_row13_col5, #T_1edd4_row13_col6, #T_1edd4_row13_col7, #T_1edd4_row13_col8, #T_1edd4_row13_col12, #T_1edd4_row13_col13, #T_1edd4_row14_col0, #T_1edd4_row14_col1, #T_1edd4_row14_col2, #T_1edd4_row14_col3, #T_1edd4_row14_col5, #T_1edd4_row14_col6, #T_1edd4_row14_col7, #T_1edd4_row14_col8, #T_1edd4_row14_col11, #T_1edd4_row14_col13, #T_1edd4_row15_col0, #T_1edd4_row15_col1, #T_1edd4_row15_col2, #T_1edd4_row15_col3, #T_1edd4_row15_col4, #T_1edd4_row15_col5, #T_1edd4_row15_col6, #T_1edd4_row15_col7, #T_1edd4_row15_col8, #T_1edd4_row15_col9, #T_1edd4_row15_col10, #T_1edd4_row15_col13, #T_1edd4_row15_col14 {
#   background-color: green;
# }
# #T_1edd4_row0_col9, #T_1edd4_row0_col10, #T_1edd4_row0_col11, #T_1edd4_row0_col12, #T_1edd4_row0_col14, #T_1edd4_row0_col15, #T_1edd4_row0_col16, #T_1edd4_row0_col17, #T_1edd4_row0_col18, #T_1edd4_row0_col19, #T_1edd4_row0_col20, #T_1edd4_row0_col21, #T_1edd4_row0_col22, #T_1edd4_row1_col9, #T_1edd4_row1_col10, #T_1edd4_row1_col11, #T_1edd4_row1_col12, #T_1edd4_row2_col9, #T_1edd4_row2_col10, #T_1edd4_row2_col11, #T_1edd4_row2_col12, #T_1edd4_row2_col14, #T_1edd4_row2_col15, #T_1edd4_row3_col9, #T_1edd4_row3_col10, #T_1edd4_row3_col11, #T_1edd4_row3_col12, #T_1edd4_row3_col14, #T_1edd4_row3_col16, #T_1edd4_row3_col17, #T_1edd4_row3_col18, #T_1edd4_row3_col19, #T_1edd4_row3_col20, #T_1edd4_row3_col21, #T_1edd4_row3_col22, #T_1edd4_row4_col11, #T_1edd4_row5_col7, #T_1edd4_row6_col10, #T_1edd4_row7_col14, #T_1edd4_row8_col9, #T_1edd4_row8_col10, #T_1edd4_row8_col11, #T_1edd4_row8_col14, #T_1edd4_row9_col9, #T_1edd4_row9_col10, #T_1edd4_row9_col11, #T_1edd4_row9_col12, #T_1edd4_row9_col15, #T_1edd4_row10_col10, #T_1edd4_row10_col12, #T_1edd4_row10_col14, #T_1edd4_row10_col16, #T_1edd4_row10_col17, #T_1edd4_row11_col10, #T_1edd4_row11_col14, #T_1edd4_row12_col11, #T_1edd4_row12_col16, #T_1edd4_row12_col18, #T_1edd4_row12_col19, #T_1edd4_row12_col20, #T_1edd4_row12_col21, #T_1edd4_row13_col10, #T_1edd4_row13_col14, #T_1edd4_row13_col16, #T_1edd4_row14_col4, #T_1edd4_row15_col22 {
#   background-color: red;
# }
# #T_1edd4_row1_col13, #T_1edd4_row1_col14, #T_1edd4_row1_col15, #T_1edd4_row1_col16, #T_1edd4_row1_col17, #T_1edd4_row1_col18, #T_1edd4_row1_col19, #T_1edd4_row1_col20, #T_1edd4_row1_col21, #T_1edd4_row1_col22, #T_1edd4_row2_col16, #T_1edd4_row2_col17, #T_1edd4_row2_col18, #T_1edd4_row2_col19, #T_1edd4_row2_col20, #T_1edd4_row2_col21, #T_1edd4_row2_col22, #T_1edd4_row3_col15, #T_1edd4_row4_col12, #T_1edd4_row4_col13, #T_1edd4_row4_col14, #T_1edd4_row4_col15, #T_1edd4_row4_col16, #T_1edd4_row4_col17, #T_1edd4_row4_col18, #T_1edd4_row4_col19, #T_1edd4_row4_col20, #T_1edd4_row4_col21, #T_1edd4_row4_col22, #T_1edd4_row5_col9, #T_1edd4_row5_col10, #T_1edd4_row5_col11, #T_1edd4_row5_col12, #T_1edd4_row5_col13, #T_1edd4_row5_col14, #T_1edd4_row5_col15, #T_1edd4_row5_col16, #T_1edd4_row5_col17, #T_1edd4_row5_col18, #T_1edd4_row5_col19, #T_1edd4_row5_col20, #T_1edd4_row5_col21, #T_1edd4_row5_col22, #T_1edd4_row6_col9, #T_1edd4_row6_col11, #T_1edd4_row6_col13, #T_1edd4_row6_col14, #T_1edd4_row6_col15, #T_1edd4_row6_col16, #T_1edd4_row6_col17, #T_1edd4_row6_col18, #T_1edd4_row6_col19, #T_1edd4_row6_col20, #T_1edd4_row6_col21, #T_1edd4_row6_col22, #T_1edd4_row7_col9, #T_1edd4_row7_col10, #T_1edd4_row7_col11, #T_1edd4_row7_col15, #T_1edd4_row7_col16, #T_1edd4_row7_col17, #T_1edd4_row7_col18, #T_1edd4_row7_col19, #T_1edd4_row7_col20, #T_1edd4_row7_col21, #T_1edd4_row7_col22, #T_1edd4_row8_col15, #T_1edd4_row8_col16, #T_1edd4_row8_col17, #T_1edd4_row8_col18, #T_1edd4_row8_col19, #T_1edd4_row8_col20, #T_1edd4_row8_col21, #T_1edd4_row8_col22, #T_1edd4_row9_col14, #T_1edd4_row9_col16, #T_1edd4_row9_col17, #T_1edd4_row9_col18, #T_1edd4_row9_col19, #T_1edd4_row9_col20, #T_1edd4_row9_col21, #T_1edd4_row9_col22, #T_1edd4_row10_col9, #T_1edd4_row10_col15, #T_1edd4_row10_col18, #T_1edd4_row10_col19, #T_1edd4_row10_col20, #T_1edd4_row10_col21, #T_1edd4_row10_col22, #T_1edd4_row11_col9, #T_1edd4_row11_col12, #T_1edd4_row11_col15, #T_1edd4_row11_col16, #T_1edd4_row11_col17, #T_1edd4_row11_col18, #T_1edd4_row11_col19, #T_1edd4_row11_col20, #T_1edd4_row11_col21, #T_1edd4_row11_col22, #T_1edd4_row12_col4, #T_1edd4_row12_col9, #T_1edd4_row12_col10, #T_1edd4_row12_col12, #T_1edd4_row12_col14, #T_1edd4_row12_col15, #T_1edd4_row12_col17, #T_1edd4_row12_col22, #T_1edd4_row13_col4, #T_1edd4_row13_col9, #T_1edd4_row13_col11, #T_1edd4_row13_col15, #T_1edd4_row13_col17, #T_1edd4_row13_col18, #T_1edd4_row13_col19, #T_1edd4_row13_col20, #T_1edd4_row13_col21, #T_1edd4_row13_col22, #T_1edd4_row14_col9, #T_1edd4_row14_col10, #T_1edd4_row14_col12, #T_1edd4_row14_col14, #T_1edd4_row14_col15, #T_1edd4_row14_col16, #T_1edd4_row14_col17, #T_1edd4_row14_col18, #T_1edd4_row14_col19, #T_1edd4_row14_col20, #T_1edd4_row14_col21, #T_1edd4_row14_col22, #T_1edd4_row15_col11, #T_1edd4_row15_col12, #T_1edd4_row15_col15, #T_1edd4_row15_col16, #T_1edd4_row15_col17, #T_1edd4_row15_col18, #T_1edd4_row15_col19, #T_1edd4_row15_col20, #T_1edd4_row15_col21 {
#   background-color: yellow;
# }
# </style>
# <table id="T_1edd4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >all_data</th>
#       <th class="col_heading l
# Legend:
# all_data: The aggregated data, e.g. ("all_data", "Macrophage") - all macrophages, ("C152", "all_data") - all cells from C152.
# ✓: Data is processed and ready for use
# ?: Failed to detect the data file, although the corresponding cell type is present in patient
# ✕: The corresponding cell type is not present in patient
